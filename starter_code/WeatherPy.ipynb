# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 553

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | delta
# Processing Record 2 of Set 1 | isafjordur
# Processing Record 3 of Set 1 | bilibino
# Processing Record 4 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 5 of Set 1 | strathalbyn
# Processing Record 6 of Set 1 | waitangi
# Processing Record 7 of Set 1 | vallenar
# Processing Record 8 of Set 1 | verkhniy baskunchak
# Processing Record 9 of Set 1 | trenggalek
# Processing Record 10 of Set 1 | wailua homesteads
# Processing Record 11 of Set 1 | brooks
# Processing Record 12 of Set 1 | mata-utu
# Processing Record 13 of Set 1 | anadyr
# Processing Record 14 of Set 1 | avarua
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | west island
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | suva
# Processing Record 19 of Set 1 | vicuna mackenna
# Processing Record 20 of Set 1 | bac lieu
# Processing Record 21 of Set 1 | prabumulih
# Processing Record 22 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | campoverde
# Processing Record 25 of Set 1 | la sarre
# Processing Record 26 of Set 1 | port-aux-francais
# Processing Record 27 of Set 1 | iqaluit
# Processing Record 28 of Set 1 | whitehorse
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | alaghsas
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | acarau
# Processing Record 33 of Set 1 | adamstown
# Processing Record 34 of Set 1 | otjimbingwe
# Processing Record 35 of Set 1 | hamilton
# Processing Record 36 of Set 1 | hell-ville
# Processing Record 37 of Set 1 | riberalta
# Processing Record 38 of Set 1 | sisimiut
# Processing Record 39 of Set 1 | st. john's
# Processing Record 40 of Set 1 | grand falls-windsor
# Processing Record 41 of Set 1 | vila franca do campo
# Processing Record 42 of Set 1 | georgetown
# Processing Record 43 of Set 1 | papatowai
# Processing Record 44 of Set 1 | bubaque
# Processing Record 45 of Set 1 | nantucket
# Processing Record 46 of Set 1 | horta
# Processing Record 47 of Set 1 | novodvinsk
# Processing Record 48 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 49 of Set 1 | kailua-kona
# Processing Record 50 of Set 1 | bossangoa
# Processing Record 0 of Set 2 | east london
# Processing Record 1 of Set 2 | hawaiian paradise park
# Processing Record 2 of Set 2 | mendoza
# Processing Record 3 of Set 2 | nechi
# Processing Record 4 of Set 2 | salahonda
# Processing Record 5 of Set 2 | invercargill
# Processing Record 6 of Set 2 | enewetak
# Processing Record 7 of Set 2 | olonkinbyen
# Processing Record 8 of Set 2 | tazacorte
# Processing Record 9 of Set 2 | iquitos
# Processing Record 10 of Set 2 | puerto natales
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | edinburgh of the seven seas
# Processing Record 14 of Set 2 | mount pearl
# Processing Record 15 of Set 2 | bakanas
# Processing Record 16 of Set 2 | tangalle
# Processing Record 17 of Set 2 | amroha
# Processing Record 18 of Set 2 | rio gallegos
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | mandvi
# Processing Record 21 of Set 2 | lesnoy
# Processing Record 22 of Set 2 | vilyuchinsk
# Processing Record 23 of Set 2 | aasiaat
# Processing Record 24 of Set 2 | buchanan
# Processing Record 25 of Set 2 | ancud
# Processing Record 26 of Set 2 | stanley
# Processing Record 27 of Set 2 | bayanhongor
# Processing Record 28 of Set 2 | auchi
# Processing Record 29 of Set 2 | antsiranana
# Processing Record 30 of Set 2 | klyuchi
# Processing Record 31 of Set 2 | curitiba
# Processing Record 32 of Set 2 | daru
# Processing Record 33 of Set 2 | port mathurin
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | lagoa formosa
# Processing Record 37 of Set 2 | codrington
# Processing Record 38 of Set 2 | bethel
# Processing Record 39 of Set 2 | kayangel
# Processing Record 40 of Set 2 | nar'yan-mar
# Processing Record 41 of Set 2 | menongue
# Processing Record 42 of Set 2 | hailar
# Processing Record 43 of Set 2 | uturoa
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | qianzhou
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | nova sintra
# Processing Record 48 of Set 2 | la puebla de montalban
# Processing Record 49 of Set 2 | port shepstone
# Processing Record 0 of Set 3 | college
# Processing Record 1 of Set 3 | farkhar
# Processing Record 2 of Set 3 | kudahuvadhoo
# Processing Record 3 of Set 3 | ierapetra
# Processing Record 4 of Set 3 | badger
# Processing Record 5 of Set 3 | puerto carreno
# Processing Record 6 of Set 3 | riyadh
# Processing Record 7 of Set 3 | coquimbo
# Processing Record 8 of Set 3 | ribeira grande
# Processing Record 9 of Set 3 | utrik
# Processing Record 10 of Set 3 | colonia
# Processing Record 11 of Set 3 | albany
# Processing Record 12 of Set 3 | motueka
# Processing Record 13 of Set 3 | labrador city
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | belinskiy
# Processing Record 16 of Set 3 | kapuskasing
# Processing Record 17 of Set 3 | rapid valley
# Processing Record 18 of Set 3 | san antonio de pale
# Processing Record 19 of Set 3 | flagstaff
# Processing Record 20 of Set 3 | newman
# Processing Record 21 of Set 3 | luena
# Processing Record 22 of Set 3 | robertsport
# Processing Record 23 of Set 3 | rongelap
# Processing Record 24 of Set 3 | tromso
# Processing Record 25 of Set 3 | saint-philippe
# Processing Record 26 of Set 3 | saipan
# Processing Record 27 of Set 3 | fenoarivo be
# Processing Record 28 of Set 3 | vorgashor
# Processing Record 29 of Set 3 | afaahiti
# Processing Record 30 of Set 3 | turbat
# Processing Record 31 of Set 3 | yellowknife
# Processing Record 32 of Set 3 | lihue
# Processing Record 33 of Set 3 | goribidnur
# Processing Record 34 of Set 3 | korla
# Processing Record 35 of Set 3 | tralee
# Processing Record 36 of Set 3 | port elizabeth
# Processing Record 37 of Set 3 | atafu village
# Processing Record 38 of Set 3 | tazovsky
# Processing Record 39 of Set 3 | holualoa
# Processing Record 40 of Set 3 | saminaka
# Processing Record 41 of Set 3 | otavalo
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | oranjemund
# Processing Record 44 of Set 3 | cuenca
# Processing Record 45 of Set 3 | san clemente del tuyu
# Processing Record 46 of Set 3 | cable beach
# City not found. Skipping...
# Processing Record 47 of Set 3 | harstad
# Processing Record 48 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 49 of Set 3 | dove valley
# Processing Record 0 of Set 4 | san andres
# Processing Record 1 of Set 4 | kasaragod
# Processing Record 2 of Set 4 | al lagowa
# Processing Record 3 of Set 4 | lompoc
# Processing Record 4 of Set 4 | mabaruma
# Processing Record 5 of Set 4 | ismailia
# Processing Record 6 of Set 4 | celestun
# Processing Record 7 of Set 4 | alofi
# Processing Record 8 of Set 4 | ujae
# Processing Record 9 of Set 4 | piton saint-leu
# Processing Record 10 of Set 4 | cambria
# Processing Record 11 of Set 4 | san patricio
# Processing Record 12 of Set 4 | port douglas
# Processing Record 13 of Set 4 | kerikeri
# Processing Record 14 of Set 4 | khandyga
# Processing Record 15 of Set 4 | narvik
# Processing Record 16 of Set 4 | margaret river
# Processing Record 17 of Set 4 | ayaviri
# Processing Record 18 of Set 4 | nemuro
# Processing Record 19 of Set 4 | iskateley

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                     delta   5.5000    6.0000     27.56        82
# 1                isafjordur  66.0755  -23.1240     -0.50        81
# 2                  bilibino  68.0546  166.4372    -36.87        98
# 3  petropavlovsk-kamchatsky  53.0452  158.6483    -18.08        81
# 4               strathalbyn -35.2667  138.9000     29.25        45
#
#    Cloudiness  Wind Speed Country        Date
# 0           0        2.23      NG  1707778494
# 1         100       10.05      IS  1707778552
# 2          93        1.00      RU  1707778552
# 3           0        4.00      RU  1707778553
# 4           7        4.82      AU  1707778554

# %%
# Export 
the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           delta   5.5000    6.0000     27.56        82
# 1                      isafjordur  66.0755  -23.1240     -0.50        81
# 2                        bilibino  68.0546  166.4372    -36.87        98
# 3        petropavlovsk-kamchatsky  53.0452  158.6483    -18.08        81
# 4                     strathalbyn -35.2667  138.9000     29.25        45
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        2.23      NG  1707778494
# 1               100       10.05      IS  1707778552
# 2                93        1.00      RU  1707778552
# 3                 0        4.00      RU  1707778553
# 4                 7        4.82      AU  1707778554

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
## Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date=city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           delta   5.5000    6.0000     27.56        82
# 1                      isafjordur  66.0755  -23.1240     -0.50        81
# 2                        bilibino  68.0546  166.4372    -36.87        98
# 3        petropavlovsk-kamchatsky  53.0452  158.6483    -18.08        81
# 7             verkhniy baskunchak  48.2256   46.7217      1.76       100
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                 0        2.23      NG  1707778494
# 1               100       10.05      IS  1707778552
# 2                93        1.00      RU  1707778552
# 3                 0        4.00      RU  1707778553
# 7               100        3.26      RU  1707778556

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude <= 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4        strathalbyn -35.2667  138.9000     29.25        45           7
# 5           waitangi -43.9535 -176.5597     17.12        83          81
# 6           vallenar -28.5708  -70.7581     26.19        47           2
# 8         trenggalek  -8.0500  111.7167     24.31        93          59
# 11          mata-utu -13.2816 -176.1745     28.25        83          99
#
#          Wind Speed Country        Date
# City_ID
# 4              4.82      AU  1707778554
# 5              3.13      NZ  1707778554
# 6              2.83      CL  1707778555
# 8              0.65      ID  1707778556
# 11             8.44      WF  1707778297

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Latitude vs. Temperature in Northern Hemisphere")

# Define a function to create Linear Regression plots
def lr_funcV2(x,y,name,vbl,hemi):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {vbl} - {hemi}')
    plt.xlabel('Latitude')
    plt.ylabel(vbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    print(f'Linear equation: {line_eq}')
    plt.savefig(f"output_data/LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
name = 'NH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.79x + 35.94
# The r-value is: -0.8745947606938096

# %%
# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
name = 'SH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.21x + 27.87
# The r-value is: 0.6002799143690932

# %% [markdown]
# **Discussion about the linear relationship:** There is a strong relationship between latitude and maximum temperature. In the Northern Hemisphere, it is a negative correlation, while in the Southern Hemisphere, it is a positive correlation. Maximum Temperature increases as we approach the equator.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
name = 'NH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.49x + 52.47
# The r-value is: 0.41546374807169706

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
name = 'SH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.62x + 89.23
# The r-value is: 0.49717821539007745

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no relationship between latitude and humidity based on the data available. The linear equation for each hemisphere shows a very slightly positive correlation, which implies that proximity to the equator has no bearing on humdity. The scatter points show that the data is too spread for there to be any reliable correlation between latitude and humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
name = 'NH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.51x + 36.87
# The r-value is: 0.25106680659349273

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
name = 'SH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.7x + 72.73
# The r-value is: 0.26176240387420174

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no relationship between latitude and cloudiness based on the data available. The linear equation for each hemisphere shows a positive correlation, which implies that proximity to the equator has no bearing on cloudiness. The scatter points show that the data is too spread for there to be any reliable correlation between latitude and cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
name = 'NH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.01x + 3.95
# The r-value is: -0.08297803765191275

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid()

# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
name = 'SH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.04x + 2.79
# The r-value is: -0.21202584684610046

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no relationship between latitude and wind speed based on the data available. The r-value is low for both hemispheres and the scatter points show that the data is too spread for there to be any reliable correlation between latitude and wind speed.
