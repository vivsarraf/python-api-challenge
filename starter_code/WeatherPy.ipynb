# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 602

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}'
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric'
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather =  requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | menongue
# Processing Record 2 of Set 1 | nieuw amsterdam
# Processing Record 3 of Set 1 | flying fish cove
# Processing Record 4 of Set 1 | castelli
# Processing Record 5 of Set 1 | buguda
# Processing Record 6 of Set 1 | vilyuchinsk
# Processing Record 7 of Set 1 | isangel
# Processing Record 8 of Set 1 | shenandoah
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | baoding
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | happy valley-goose bay
# Processing Record 13 of Set 1 | vadso
# Processing Record 14 of Set 1 | tralee
# Processing Record 15 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 16 of Set 1 | lompoc
# Processing Record 17 of Set 1 | noumea
# Processing Record 18 of Set 1 | adamstown
# Processing Record 19 of Set 1 | iramuco
# Processing Record 20 of Set 1 | ajaokuta
# Processing Record 21 of Set 1 | kavaratti
# Processing Record 22 of Set 1 | edinburgh of the seven seas
# Processing Record 23 of Set 1 | pielavesi
# Processing Record 24 of Set 1 | wamba
# Processing Record 25 of Set 1 | wailua homesteads
# Processing Record 26 of Set 1 | tura
# Processing Record 27 of Set 1 | essaouira
# Processing Record 28 of Set 1 | uturoa
# Processing Record 29 of Set 1 | hailar
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | island harbour
# Processing Record 32 of Set 1 | puerto ayora
# Processing Record 33 of Set 1 | west island
# Processing Record 34 of Set 1 | gobabis
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | puerto natales
# Processing Record 37 of Set 1 | gisborne
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | canosa di puglia
# Processing Record 40 of Set 1 | nehe
# Processing Record 41 of Set 1 | khovd
# Processing Record 42 of Set 1 | valenca
# Processing Record 43 of Set 1 | saipan
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 1 | kuressaare
# Processing Record 47 of Set 1 | dakhla
# Processing Record 48 of Set 1 | gizo
# Processing Record 49 of Set 1 | ibshaway
# Processing Record 50 of Set 1 | quibala
# Processing Record 0 of Set 2 | qashyr
# Processing Record 1 of Set 2 | port-aux-francais
# Processing Record 2 of Set 2 | ayr
# Processing Record 3 of Set 2 | parry sound
# Processing Record 4 of Set 2 | farnham
# Processing Record 5 of Set 2 | grytviken
# Processing Record 6 of Set 2 | cairns city
# City not found. Skipping...
# Processing Record 7 of Set 2 | badger
# Processing Record 8 of Set 2 | blackmans bay
# Processing Record 9 of Set 2 | okhotsk
# Processing Record 10 of Set 2 | villa yapacani
# Processing Record 11 of Set 2 | igarka
# Processing Record 12 of Set 2 | midvagur
# Processing Record 13 of Set 2 | ust'-ilimsk
# Processing Record 14 of Set 2 | waitangi
# Processing Record 15 of Set 2 | guangzhou
# Processing Record 16 of Set 2 | mejit
# Processing Record 17 of Set 2 | awjilah
# Processing Record 18 of Set 2 | holualoa
# Processing Record 19 of Set 2 | newman
# Processing Record 20 of Set 2 | selfoss
# Processing Record 21 of Set 2 | mount pearl
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | hawaiian paradise park
# Processing Record 24 of Set 2 | turpan
# Processing Record 25 of Set 2 | mount gambier
# Processing Record 26 of Set 2 | timbuktu
# Processing Record 27 of Set 2 | barra de santo antonio
# Processing Record 28 of Set 2 | puerto armuelles
# Processing Record 29 of Set 2 | qamdo
# Processing Record 30 of Set 2 | tiksi
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | dingli
# Processing Record 33 of Set 2 | ollon
# Processing Record 34 of Set 2 | college
# Processing Record 35 of Set 2 | la sarre
# Processing Record 36 of Set 2 | kirensk
# Processing Record 37 of Set 2 | constantia
# Processing Record 38 of Set 2 | sturgis
# Processing Record 39 of Set 2 | kailua-kona
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | papatowai
# Processing Record 42 of Set 2 | isafjordur
# Processing Record 43 of Set 2 | suoyarvi
# Processing Record 44 of Set 2 | nova sintra
# Processing Record 45 of Set 2 | tazacorte
# Processing Record 46 of Set 2 | luza
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | ushuaia
# Processing Record 49 of Set 2 | laishevo
# Processing Record 0 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 1 of Set 3 | kabalo
# Processing Record 2 of Set 3 | conde
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | akureyri
# Processing Record 5 of Set 3 | bandon
# Processing Record 6 of Set 3 | invercargill
# Processing Record 7 of Set 3 | kangasniemi
# Processing Record 8 of Set 3 | raja
# Processing Record 9 of Set 3 | greymouth
# Processing Record 10 of Set 3 | santiago de cao
# Processing Record 11 of Set 3 | olonkinbyen
# Processing Record 12 of Set 3 | chimore
# Processing Record 13 of Set 3 | leninsk-kuznetsky
# Processing Record 14 of Set 3 | selkirk
# Processing Record 15 of Set 3 | nogliki
# Processing Record 16 of Set 3 | alta
# Processing Record 17 of Set 3 | mosjoen
# Processing Record 18 of Set 3 | klyuchi
# Processing Record 19 of Set 3 | minas de marcona
# Processing Record 20 of Set 3 | jeremie
# Processing Record 21 of Set 3 | mao
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | chibougamau
# Processing Record 25 of Set 3 | hasaki
# Processing Record 26 of Set 3 | san juan
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | kazanskoye
# Processing Record 29 of Set 3 | tazovsky
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | itamaraju
# Processing Record 32 of Set 3 | oodweyne
# Processing Record 33 of Set 3 | kourou
# Processing Record 34 of Set 3 | bilibino
# Processing Record 35 of Set 3 | berdigestyakh
# Processing Record 36 of Set 3 | cukai
# Processing Record 37 of Set 3 | el gouna
# Processing Record 38 of Set 3 | atafu village
# Processing Record 39 of Set 3 | borogontsy
# Processing Record 40 of Set 3 | harstad
# Processing Record 41 of Set 3 | cape town
# Processing Record 42 of Set 3 | hermanus
# Processing Record 43 of Set 3 | dudinka
# Processing Record 44 of Set 3 | asaita
# Processing Record 45 of Set 3 | anori
# Processing Record 46 of Set 3 | sheksna
# Processing Record 47 of Set 3 | codrington
# Processing Record 48 of Set 3 | muroto-misakicho
# Processing Record 49 of Set 3 | namibe
# Processing Record 0 of Set 4 | am djarass
# City not found. Skipping...
# Processing Record 1 of Set 4 | port hedland
# Processing Record 2 of Set 4 | glubokoye
# Processing Record 3 of Set 4 | arkhangel'sk
# Processing Record 4 of Set 4 | tateyama
# Processing Record 5 of Set 4 | margaret river
# Processing Record 6 of Set 4 | ancud
# Processing Record 7 of Set 4 | susuman
# Processing Record 8 of Set 4 | bankim
# Processing Record 9 of Set 4 | ketchikan
# Processing Record 10 of Set 4 | thompson
# Processing Record 11 of Set 4 | yurty
# Processing Record 12 of Set 4 | tsiombe
# Processing Record 13 of Set 4 | vila franca do campo
# Processing Record 14 of Set 4 | enewetak
# Processing Record 15 of Set 4 | arthur's town
# City not found. Skipping...
# Processing Record 16 of Set 4 | es castell
# Processing Record 17 of Set 4 | arno
# Processing Record 18 of Set 4 | iskateley
# Processing Record 19 of Set 4 | nuestra senora del rosario de caa cati
# Processing Record 20 of Set 4 | bredy
# Processing Record 21 of Set 4 | grantsville
# Processing Record 22 of Set 4 | utrik
# Processing Record 23 of Set 4 | acarau
# Processing Record 24 of Set 4 | leava
# Processing Record 25 of Set 4 | askino
# Processing Record 26 of Set 4 | wanning
# Processing Record 27 of Set 4 | ozu
# Processing Record 28 of Set 4 | hadibu
# Processing Record 29 of Set 4 | whitehorse
# Processing Record 30 of Set 4 | springbok
# Processing Record 31 of Set 4 | shingu
# Processing Record 32 of Set 4 | walvis bay
# Processing Record 33 of Set 4 | aasiaat
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | alcaniz
# Processing Record 36 of Set 4 | inirida
# Processing Record 37 of Set 4 | acarlar
# Processing Record 38 of Set 4 | talnakh
# Processing Record 39 of Set 4 | stanley
# Processing Record 40 of Set 4 | rawson
# Processing Record 41 of Set 4 | pont rouge
# Processing Record 42 of Set 4 | hobyo
# Processing Record 43 of Set 4 | alice springs
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | mombasa
# Processing Record 46 of Set 4 | weno
# Processing Record 47 of Set 4 | ghat
# Processing Record 48 of Set 4 | rio grande
# Processing Record 49 of Set 4 | nchelenge
# Processing Record 0 of Set 5 | severo-yeniseyskiy
# Processing Record 1 of Set 5 | nabire
# Processing Record 2 of Set 5 | svetlyy
# Processing Record 3 of Set 5 | leua
# Processing Record 4 of Set 5 | amalapuram
# Processing Record 5 of Set 5 | courtenay
# Processing Record 6 of Set 5 | kamina
# Processing Record 7 of Set 5 | pec
# Processing Record 8 of Set 5 | new norfolk
# Processing Record 9 of Set 5 | guerrero negro
# Processing Record 10 of Set 5 | joshimath
# Processing Record 11 of Set 5 | lihue
# Processing Record 12 of Set 5 | antigonish
# Processing Record 13 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 14 of Set 5 | nurota
# Processing Record 15 of Set 5 | porto novo
# Processing Record 16 of Set 5 | callao
# Processing Record 17 of Set 5 | thinadhoo
# Processing Record 18 of Set 5 | muzayri'
# City not found. Skipping...
# Processing Record 19 of Set 5 | quellon
# Processing Record 20 of Set 5 | tubarjal
# Processing Record 21 of Set 5 | karratha
# Processing Record 22 of Set 5 | lebu
# Processing Record 23 of Set 5 | fort mcmurray
# Processing Record 24 of Set 5 | port mathurin
# Processing Record 25 of Set 5 | novyy urgal
# Processing Record 26 of Set 5 | badiyah
# Processing Record 27 of Set 5 | sanming
# Processing Record 28 of Set 5 | massawa
# Processing Record 29 of Set 5 | yambio
# Processing Record 30 of Set 5 | bardai
# Processing Record 31 of Set 5 | khash
# Processing Record 32 of Set 5 | novodvinsk
# Processing Record 33 of Set 5 | khandyga
# Processing Record 34 of Set 5 | talakan
# Processing Record 35 of Set 5 | togur
# Processing Record 36 of Set 5 | naama
# Processing Record 37 of Set 5 | taiohae
# City not found. Skipping...
# Processing Record 38 of Set 5 | jianshui
# Processing Record 39 of Set 5 | cortez
# Processing Record 40 of Set 5 | nova vicosa
# Processing Record 41 of Set 5 | corsicana
# Processing Record 42 of Set 5 | crane
# Processing Record 43 of Set 5 | yangor
# City not found. Skipping...
# Processing Record 44 of Set 5 | sinjar
# Processing Record 45 of Set 5 | sabang
# Processing Record 46 of Set 5 | tres barras
# Processing Record 47 of Set 5 | papao
# Processing Record 48 of Set 5 | dingle
# Processing Record 49 of Set 5 | pariang
# City not found. Skipping...
# Processing Record 0 of Set 6 | fortuna
# Processing Record 1 of Set 6 | toga village
# City not found. Skipping...
# Processing Record 2 of Set 6 | oliver
# Processing Record 3 of Set 6 | ormara
# Processing Record 4 of Set 6 | acapulco de juarez
# Processing Record 5 of Set 6 | pisco
# Processing Record 6 of Set 6 | galveston
# Processing Record 7 of Set 6 | pimentel
# Processing Record 8 of Set 6 | sishilichengzi
# City not found. Skipping...
# Processing Record 9 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 10 of Set 6 | coquimbo
# Processing Record 11 of Set 6 | plastun
# Processing Record 12 of Set 6 | ta`u
# Processing Record 13 of Set 6 | al artawiyah
# Processing Record 14 of Set 6 | touros
# Processing Record 15 of Set 6 | kone
# Processing Record 16 of Set 6 | vorgashor
# Processing Record 17 of Set 6 | howard springs
# Processing Record 18 of Set 6 | longmen
# Processing Record 19 of Set 6 | duong dong
# Processing Record 20 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 21 of Set 6 | portland
# Processing Record 22 of Set 6 | longyearbyen
# Processing Record 23 of Set 6 | fale old settlement
# Processing Record 24 of Set 6 | ulsteinvik
# Processing Record 25 of Set 6 | natal
# Processing Record 26 of Set 6 | kimbe
# Processing Record 27 of Set 6 | tromso
# Processing Record 28 of Set 6 | sabt alalayah
# City not found. Skipping...
# Processing Record 29 of Set 6 | antsiranana
# Processing Record 30 of Set 6 | castlegar
# Processing Record 31 of Set 6 | bodo
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | hammerfest
# Processing Record 34 of Set 6 | st. john's
# Processing Record 35 of Set 6 | gamba
# Processing Record 36 of Set 6 | urengoy
# Processing Record 37 of Set 6 | hamilton
# Processing Record 38 of Set 6 | muang xay
# Processing Record 39 of Set 6 | les sables-d'olonne
# Processing Record 40 of Set 6 | abra pampa
# Processing Record 41 of Set 6 | paraiso
# Processing Record 42 of Set 6 | tofol
# Processing Record 43 of Set 6 | yola
# Processing Record 44 of Set 6 | sechura
# Processing Record 45 of Set 6 | seinajoki
# Processing Record 46 of Set 6 | nuku'alofa
# Processing Record 47 of Set 6 | san andres
# Processing Record 48 of Set 6 | san luis de la loma
# Processing Record 49 of Set 6 | ciudad lazaro cardenas
# Processing Record 0 of Set 7 | bamut
# Processing Record 1 of Set 7 | mapleton
# Processing Record 2 of Set 7 | aldinga beach
# Processing Record 3 of Set 7 | sinabang
# Processing Record 4 of Set 7 | saint-philippe
# Processing Record 5 of Set 7 | keetmanshoop
# Processing Record 6 of Set 7 | cabo san lucas
# Processing Record 7 of Set 7 | taltal
# Processing Record 8 of Set 7 | lib
# Processing Record 9 of Set 7 | moranbah
# Processing Record 10 of Set 7 | takamaka
# City not found. Skipping...
# Processing Record 11 of Set 7 | sao gabriel da cachoeira
# Processing Record 12 of Set 7 | nemuro
# Processing Record 13 of Set 7 | kiunga
# Processing Record 14 of Set 7 | ambon
# Processing Record 15 of Set 7 | morondava
# Processing Record 16 of Set 7 | fort bragg
# Processing Record 17 of Set 7 | anaconda
# Processing Record 18 of Set 7 | chonchi
# Processing Record 19 of Set 7 | aykhal
# Processing Record 20 of Set 7 | beyneu
# Processing Record 21 of Set 7 | bryne
# Processing Record 22 of Set 7 | sharur city
# City not found. Skipping...
# Processing Record 23 of Set 7 | caleta de carquin
# Processing Record 24 of Set 7 | soe
# Processing Record 25 of Set 7 | remire-montjoly
# Processing Record 26 of Set 7 | ishigaki
# Processing Record 27 of Set 7 | stephenville
# Processing Record 28 of Set 7 | port lincoln
# Processing Record 29 of Set 7 | kapa'a
# Processing Record 30 of Set 7 | alaghsas
# Processing Record 31 of Set 7 | nagqu
# Processing Record 32 of Set 7 | geraldton
# Processing Record 33 of Set 7 | beroroha
# Processing Record 34 of Set 7 | abalak
# Processing Record 35 of Set 7 | jining
# Processing Record 36 of Set 7 | armacao de buzios
# Processing Record 37 of Set 7 | magadan
# Processing Record 38 of Set 7 | ulladulla
# Processing Record 39 of Set 7 | kirakira
# Processing Record 40 of Set 7 | udachny
# Processing Record 41 of Set 7 | dwarka
# Processing Record 42 of Set 7 | saint-francois
# Processing Record 43 of Set 7 | tumayr
# Processing Record 44 of Set 7 | massena
# Processing Record 45 of Set 7 | mishkino
# Processing Record 46 of Set 7 | jalai nur
# Processing Record 47 of Set 7 | morant bay
# Processing Record 48 of Set 7 | buala
# Processing Record 49 of Set 7 | belmonte
# Processing Record 0 of Set 8 | larreynaga
# Processing Record 1 of Set 8 | bikenibeu village
# Processing Record 2 of Set 8 | arraial do cabo
# Processing Record 3 of Set 8 | new plymouth
# Processing Record 4 of Set 8 | gaspe
# Processing Record 5 of Set 8 | kattivakkam
# Processing Record 6 of Set 8 | bandarbeyla
# Processing Record 7 of Set 8 | afaahiti
# Processing Record 8 of Set 8 | nasiriyah
# Processing Record 9 of Set 8 | ust-nera
# Processing Record 10 of Set 8 | las tablas
# Processing Record 11 of Set 8 | kingston
# Processing Record 12 of Set 8 | mbaiki
# Processing Record 13 of Set 8 | gadzhiyevo
# Processing Record 14 of Set 8 | egilsstadir
# Processing Record 15 of Set 8 | salahonda
# Processing Record 16 of Set 8 | el charco
# Processing Record 17 of Set 8 | haiku-pauwela
# Processing Record 18 of Set 8 | palmer
# Processing Record 19 of Set 8 | cabedelo
# Processing Record 20 of Set 8 | saudarkrokur
# Processing Record 21 of Set 8 | lata
# Processing Record 22 of Set 8 | harper
# Processing Record 23 of Set 8 | catalhoyuk
# Processing Record 24 of Set 8 | qaqortoq
# Processing Record 25 of Set 8 | bairnsdale
# Processing Record 26 of Set 8 | weligama
# Processing Record 27 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 28 of Set 8 | toliara
# Processing Record 29 of Set 8 | taoudenni
# Processing Record 30 of Set 8 | malpur
# Processing Record 31 of Set 8 | lawas
# Processing Record 32 of Set 8 | ust'-kulom
# Processing Record 33 of Set 8 | cambria
# Processing Record 34 of Set 8 | san antonio de pale
# Processing Record 35 of Set 8 | korotchaevo
# City not found. Skipping...
# Processing Record 36 of Set 8 | rio grande city
# Processing Record 37 of Set 8 | yeppoon
# Processing Record 38 of Set 8 | morteros
# Processing Record 39 of Set 8 | laojunmiao
# Processing Record 40 of Set 8 | boulsa
# Processing Record 41 of Set 8 | lorengau
# Processing Record 42 of Set 8 | kaoma
# Processing Record 43 of Set 8 | waddan
# Processing Record 44 of Set 8 | taos
# Processing Record 45 of Set 8 | polyarnyy
# Processing Record 46 of Set 8 | nar'yan-mar
# Processing Record 47 of Set 8 | luoyang
# Processing Record 48 of Set 8 | keflavik
# Processing Record 49 of Set 8 | rongelap
# Processing Record 0 of Set 9 | lundazi
# Processing Record 1 of Set 9 | el sauce
# Processing Record 2 of Set 9 | coronel suarez
# Processing Record 3 of Set 9 | elk city
# Processing Record 4 of Set 9 | qapqal
# City not found. Skipping...
# Processing Record 5 of Set 9 | pemangkat
# Processing Record 6 of Set 9 | ivdel'
# Processing Record 7 of Set 9 | kamiiso
# Processing Record 8 of Set 9 | ayaguz
# City not found. Skipping...
# Processing Record 9 of Set 9 | opuwo
# Processing Record 10 of Set 9 | hadim
# Processing Record 11 of Set 9 | waingapu
# Processing Record 12 of Set 9 | we
# City not found. Skipping...
# Processing Record 13 of Set 9 | castlemaine
# Processing Record 14 of Set 9 | aktobe
# Processing Record 15 of Set 9 | yarmouth
# Processing Record 16 of Set 9 | kununurra
# Processing Record 17 of Set 9 | vrangel'
# Processing Record 18 of Set 9 | ifakara
# Processing Record 19 of Set 9 | salekhard
# Processing Record 20 of Set 9 | dharampuri
# Processing Record 21 of Set 9 | kenai
# Processing Record 22 of Set 9 | kapuskasing
# Processing Record 23 of Set 9 | chernyshevskiy
# Processing Record 24 of Set 9 | myeik
# Processing Record 25 of Set 9 | nishinoomote
# Processing Record 26 of Set 9 | maloye ganyushkino
# Processing Record 27 of Set 9 | doka
# Processing Record 28 of Set 9 | cartagena del chaira
# Processing Record 29 of Set 9 | itoman
# Processing Record 30 of Set 9 | zuyevka
# Processing Record 31 of Set 9 | sao joaquim
# Processing Record 32 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 33 of Set 9 | banda aceh
# Processing Record 34 of Set 9 | karwar
# Processing Record 35 of Set 9 | mossel bay
# Processing Record 36 of Set 9 | ben gardane
# Processing Record 37 of Set 9 | anadyr
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | daru
# Processing Record 40 of Set 9 | extrema
# Processing Record 41 of Set 9 | pyay
# Processing Record 42 of Set 9 | juye
# Processing Record 43 of Set 9 | tibanbang
# Processing Record 44 of Set 9 | simplicio mendes
# Processing Record 45 of Set 9 | pavlodar
# Processing Record 46 of Set 9 | rayevskiy
# Processing Record 47 of Set 9 | dori
# Processing Record 48 of Set 9 | arroyo
# Processing Record 49 of Set 9 | chaoyang
# Processing Record 0 of Set 10 | pacific grove
# Processing Record 1 of Set 10 | san-pedro
# Processing Record 2 of Set 10 | santiago de surco
# Processing Record 3 of Set 10 | siuna
# Processing Record 4 of Set 10 | saldanha
# Processing Record 5 of Set 10 | sonsorol village
# City not found. Skipping...
# Processing Record 6 of Set 10 | thunder bay
# Processing Record 7 of Set 10 | bechar
# Processing Record 8 of Set 10 | la'ie
# Processing Record 9 of Set 10 | makokou
# Processing Record 10 of Set 10 | lobito
# Processing Record 11 of Set 10 | murzuq
# Processing Record 12 of Set 10 | mahibadhoo
# Processing Record 13 of Set 10 | west livingston
# Processing Record 14 of Set 10 | kerikeri
# Processing Record 15 of Set 10 | sao tome
# Processing Record 16 of Set 10 | lodja
# Processing Record 17 of Set 10 | madera
# Processing Record 18 of Set 10 | nuuk
# Processing Record 19 of Set 10 | crucecita
# Processing Record 20 of Set 10 | pyt-yakh
# Processing Record 21 of Set 10 | colonia menno
# Processing Record 22 of Set 10 | maintirano
# Processing Record 23 of Set 10 | xilin hot
# Processing Record 24 of Set 10 | korla
# Processing Record 25 of Set 10 | ciocanesti
# Processing Record 26 of Set 10 | alliance
# Processing Record 27 of Set 10 | ingeniero jacobacci
# Processing Record 28 of Set 10 | coahuayana de hidalgo
# Processing Record 29 of Set 10 | viedma
# Processing Record 30 of Set 10 | retreat
# Processing Record 31 of Set 10 | masindi
# Processing Record 32 of Set 10 | fuxin
# Processing Record 33 of Set 10 | freeport
# Processing Record 34 of Set 10 | chinde
# Processing Record 35 of Set 10 | katsuren-haebaru
# Processing Record 36 of Set 10 | vashkivtsi
# Processing Record 37 of Set 10 | aromashevo
# Processing Record 38 of Set 10 | changleng
# Processing Record 39 of Set 10 | santo antonio do ica
# Processing Record 40 of Set 10 | zimovniki
# Processing Record 41 of Set 10 | orange
# Processing Record 42 of Set 10 | usinsk
# Processing Record 43 of Set 10 | gloversville
# Processing Record 44 of Set 10 | assab
# Processing Record 45 of Set 10 | bubaque
# Processing Record 46 of Set 10 | camabatela
# Processing Record 47 of Set 10 | huarmey
# Processing Record 48 of Set 10 | pervomayskaya
# Processing Record 49 of Set 10 | shimoda
# Processing Record 0 of Set 11 | sault ste. marie
# Processing Record 1 of Set 11 | jastrowie
# Processing Record 2 of Set 11 | salair
# Processing Record 3 of Set 11 | port douglas
# Processing Record 4 of Set 11 | oppdal
# Processing Record 5 of Set 11 | cable beach
# City not found. Skipping...
# Processing Record 6 of Set 11 | wattegama
# Processing Record 7 of Set 11 | pandan
# Processing Record 8 of Set 11 | san jose de jachal
# Processing Record 9 of Set 11 | colonia
# Processing Record 10 of Set 11 | manismata
# Processing Record 11 of Set 11 | nouadhibou
# Processing Record 12 of Set 11 | kemijarvi
# Processing Record 13 of Set 11 | turtas
# Processing Record 14 of Set 11 | havre
# Processing Record 15 of Set 11 | baykalovo
# Processing Record 16 of Set 11 | pikeville
# Processing Record 17 of Set 11 | wewak
# Processing Record 18 of Set 11 | palikir - national government center
# Processing Record 19 of Set 11 | cedral
# Processing Record 20 of Set 11 | kalanchak
# Processing Record 21 of Set 11 | sansanne-mango
# Processing Record 22 of Set 11 | inhambane
# Processing Record 23 of Set 11 | morehead city
# Processing Record 24 of Set 11 | alamogordo
# Processing Record 25 of Set 11 | chui
# Processing Record 26 of Set 11 | kenora
# Processing Record 27 of Set 11 | amga
# Processing Record 28 of Set 11 | kruisfontein
# Processing Record 29 of Set 11 | sao joao da barra
# Processing Record 30 of Set 11 | okakarara
# Processing Record 31 of Set 11 | yuzhno-kurilsk
# Processing Record 32 of Set 11 | luchegorsk
# Processing Record 33 of Set 11 | boden
# Processing Record 34 of Set 11 | zeya
# Processing Record 35 of Set 11 | santa maria
# Processing Record 36 of Set 11 | ouellah
# City not found. Skipping...
# Processing Record 37 of Set 11 | kalaleh
# Processing Record 38 of Set 11 | mil'kovo
# Processing Record 39 of Set 11 | inari
# Processing Record 40 of Set 11 | nadi
# Processing Record 41 of Set 11 | ilha de mocambique
# Processing Record 42 of Set 11 | malmberget
# Processing Record 43 of Set 11 | belaya kholunitsa
# Processing Record 44 of Set 11 | merowe
# Processing Record 45 of Set 11 | aginskoye
# Processing Record 46 of Set 11 | pangody
# Processing Record 47 of Set 11 | saratamata
# City not found. Skipping...
# Processing Record 48 of Set 11 | sungailiat
# Processing Record 49 of Set 11 | am timan
# Processing Record 0 of Set 12 | tual
# Processing Record 1 of Set 12 | kelibia
# Processing Record 2 of Set 12 | san patricio
# Processing Record 3 of Set 12 | dullewala
# Processing Record 4 of Set 12 | lawrenceburg
# Processing Record 5 of Set 12 | arboletes
# Processing Record 6 of Set 12 | fauske
# Processing Record 7 of Set 12 | santana
# Processing Record 8 of Set 12 | pishin
# Processing Record 9 of Set 12 | joacaba
# Processing Record 10 of Set 12 | pacho
# Processing Record 11 of Set 12 | urrao
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | prieska
# Processing Record 14 of Set 12 | fada
# Processing Record 15 of Set 12 | dubbo
# Processing Record 16 of Set 12 | port augusta
# Processing Record 17 of Set 12 | mokhsogollokh
# Processing Record 18 of Set 12 | laramie
# Processing Record 19 of Set 12 | amungan
# Processing Record 20 of Set 12 | bamboo flat
# Processing Record 21 of Set 12 | vernon
# Processing Record 22 of Set 12 | palu
# Processing Record 23 of Set 12 | luderitz
# Processing Record 24 of Set 12 | big bend
# Processing Record 25 of Set 12 | fomboni
# Processing Record 26 of Set 12 | kota bharu
# Processing Record 27 of Set 12 | siem reap
# Processing Record 28 of Set 12 | puerto baquerizo moreno
# Processing Record 29 of Set 12 | musay'id
# City not found. Skipping...
# Processing Record 30 of Set 12 | kushiro
# Processing Record 31 of Set 12 | chopinzinho
# Processing Record 32 of Set 12 | hamada
# Processing Record 33 of Set 12 | hithadhoo
# Processing Record 34 of Set 12 | dongcun
# Processing Record 35 of Set 12 | anahuac
# Processing Record 36 of Set 12 | whitefish
# Processing Record 37 of Set 12 | tucupita
# Processing Record 38 of Set 12 | lae
# Processing Record 39 of Set 12 | tangalle
# Processing Record 40 of Set 12 | kampene
# Processing Record 41 of Set 12 | lloydminster
# Processing Record 42 of Set 12 | teteven
# Processing Record 43 of Set 12 | koryazhma
# Processing Record 44 of Set 12 | bonthe
# Processing Record 45 of Set 12 | zemio
# Processing Record 46 of Set 12 | preobrazheniye
# Processing Record 47 of Set 12 | uttar char fasson
# Processing Record 48 of Set 12 | swainsboro
# Processing Record 49 of Set 12 | ciudad madero
# Processing Record 0 of Set 13 | kulhudhuffushi
# Processing Record 1 of Set 13 | springfield
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          584
# Lat           584
# Lng           584
# Max Temp      584
# Humidity      584
# Cloudiness    584
# Wind Speed    584
# Country       584
# Date          584
# dtype: int64

# %%
# Convert datetime to readable date format
#city_data_df['Date']=(pd.to_datetime(city_data_df['Date'],unit='s')).dt.date

#city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  medicine hat  50.0501 -110.6683     -1.55        75         100
# 1      santiago -33.4569  -70.6483     25.19        37           0
# 2        anadyr  64.7500  177.4833    -21.72        77          40
# 3        kargat  55.1956   80.2811    -17.50        93          98
# 4       dunedin -45.8742  170.5036     14.89        61          51
#
#    Wind Speed Country        Date
# 0        6.17      CA  1707626820
# 1        3.60      CL  1707626666
# 2        5.00      RU  1707626904
# 3        6.18      RU  1707626905
# 4        4.02      NZ  1707626906

# %%
# Convert datetime to readable date format
#city_data_df['Date']=(pd.to_datetime(city_data_df['Date'],unit='s')).dt.date
city_data_df.head()


# Export the City_Data into a csv
##city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       enewetak  11.3474  162.3373     26.46        80          96
# 1      papatowai -46.5619  169.4708     14.28        53         100
# 2     bredasdorp -34.5322   20.0403     15.88        81          46
# 3  blackmans bay -43.0167  147.3167     23.07        46          55
# 4         albany  42.6001  -73.9662      7.59        76          87
#
#    Wind Speed Country        Date
# 0       10.25      MH  1707621053
# 1        3.15      NZ  1707621054
# 2        2.28      ZA  1707621055
# 3        3.89      AU  1707621055
# 4        0.45      US  1707621056

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
